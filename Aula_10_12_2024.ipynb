# %% [markdown]
# <a href="https://colab.research.google.com/github/Antuarte/Aulas/blob/master/Aula_10_12_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Carrega o dataset
df_dsa = pd.read_csv('datasetnovo.csv')

# %%
df_dsa
# Out:
#      horas_estudo_mes  salario
# 0                  57     6813
# 1                  48     6855
# 2                  60     5801
# 3                  73     7431
# 4                  46     5475
# ..                ...      ...
# 495                58     6259
# 496                34     6099
# 497                47     6170
# 498                37     5064
# 499                29     5236
#
# [500 rows x 2 columns]

# %%
df_dsa.shape
# Out:
# (500, 2)
